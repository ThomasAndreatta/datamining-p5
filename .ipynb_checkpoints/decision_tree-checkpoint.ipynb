# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn import tree
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dataset = pd.read_csv("./dataset/feature_engineering.csv", header=0)
dataset.head(3)
# Out:
#                        programme mlcourse ircourse statcourse dbcourse  \
# 0  critical language scholarship       no       no         mu      nee
# 1                        unknown       no       no         mu      nee
# 2        artificial intelligence      yes      yes         mu       ja
#
#    knowledge     stress stress_level  bedtime bedtime_segment  sporthours  \
# 0          6  42.242203       medium        1      Late Night        10.0
# 1          6  35.000000          low        1      Late Night         4.0
# 2         14  76.000000       medium        0      Late Night         0.0
#
#   activity_intensity  byear  age  mental_age mental_biological_age  gender  \
# 0               high   2000   24          26                 older  female
# 1           moderate   1994   30          33                 older  female
# 2                low   1996   28          36                 older  female
#
#               chatGPT  random  bmonth
# 0                 yes   360.0     3.0
# 1                 yes    47.0    10.0
# 2  not willing to say    35.0     4.0

# %%
X = dataset[dataset["programme"] != "unknown"].drop(["bedtime","random","stress"], axis=1)
#v = X["programme"].value_counts()
#X = X[X["programme"].isin(v.index[v.gt(5)])]

cats = ["mlcourse","ircourse", "statcourse","dbcourse","gender","chatGPT","bedtime_segment",
            "programme","activity_intensity","mental_biological_age","stress_level"]


cats_labels = {}

for var in cats:
    posvars = []
    newcol = []  
    for line in X.index:
        if not X.loc[line,var] in posvars:
            posvars.append(X.loc[line,var])
        newcol.append(posvars.index(X.loc[line,var]))
    #print(f"{var} new ordering: {posvars}")
    cats_labels[var] = posvars
    X[var] = newcol

target = "stress_level"
y = X[target]
X = X.drop(target, axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

param_grid = {"max_depth":[2,3,4,5,7,9,None]}
estim = tree.DecisionTreeClassifier()

prog_tree_sh = GridSearchCV(estim, param_grid=param_grid, cv=5).fit(X_train, y_train)

# %%
print(prog_tree_sh.best_score_)
print(prog_tree_sh.best_params_)
tree.plot_tree(prog_tree_sh.best_estimator_)
# Out:
# 0.8071146245059289
# {'max_depth': 4}
# [Text(0.4375, 0.9, 'x[11] <= 27.5\ngini = 0.616\nsamples = 113\nvalue = [42, 53, 18]'),
#  Text(0.20833333333333334, 0.7, 'x[11] <= 26.5\ngini = 0.237\nsamples = 51\nvalue = [7.0, 44.0, 0.0]'),
#  Text(0.125, 0.5, 'x[0] <= 12.5\ngini = 0.105\nsamples = 36\nvalue = [2, 34, 0]'),
#  Text(0.08333333333333333, 0.3, 'x[10] <= 22.5\ngini = 0.056\nsamples = 35\nvalue = [1, 34, 0]'),
#  Text(0.041666666666666664, 0.1, 'gini = 0.32\nsamples = 5\nvalue = [1, 4, 0]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.16666666666666666, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.2916666666666667, 0.5, 'x[10] <= 24.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10, 0]'),
#  Text(0.25, 0.3, 'x[2] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0]'),
#  Text(0.20833333333333334, 0.1, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.2916666666666667, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3333333333333333, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.6666666666666666, 0.7, 'x[11] <= 31.5\ngini = 0.576\nsamples = 62\nvalue = [35, 9, 18]'),
#  Text(0.5, 0.5, 'x[9] <= 1999.5\ngini = 0.41\nsamples = 38\nvalue = [28, 8, 2]'),
#  Text(0.4166666666666667, 0.3, 'x[11] <= 28.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8, 0]'),
#  Text(0.375, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.4583333333333333, 0.1, 'gini = 0.408\nsamples = 14\nvalue = [10, 4, 0]'),
#  Text(0.5833333333333334, 0.3, 'x[14] <= 1.5\ngini = 0.18\nsamples = 20\nvalue = [18, 0, 2]'),
#  Text(0.5416666666666666, 0.1, 'gini = 0.1\nsamples = 19\nvalue = [18, 0, 1]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8333333333333334, 0.5, 'x[10] <= 27.5\ngini = 0.469\nsamples = 24\nvalue = [7, 1, 16]'),
#  Text(0.75, 0.3, 'x[4] <= 1.5\ngini = 0.198\nsamples = 18\nvalue = [2, 0, 16]'),
#  Text(0.7083333333333334, 0.1, 'gini = 0.111\nsamples = 17\nvalue = [1, 0, 16]'),
#  Text(0.7916666666666666, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9166666666666666, 0.3, 'x[8] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1, 0]'),
#  Text(0.875, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9583333333333334, 0.1, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]')]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
y_hat = prog_tree_sh.best_estimator_.predict(X_test)
print(accuracy_score(y_test, y_hat)*100)
cm = confusion_matrix(y_test, y_hat)
print(cm)
ConfusionMatrixDisplay(cm / cm.sum(axis=1)[:,None]).plot()
# Out:
# 78.0701754385965
# [[17  7  3]
#  [ 9 56  0]
#  [ 4  2 16]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
y_hat = prog_tree_sh.best_estimator_.predict(X_test)
print(mean_squared_error(y_test, y_hat))
print(mean_absolute_error(y_test, y_hat))
# Out:
# 0.40350877192982454
# 0.2807017543859649
